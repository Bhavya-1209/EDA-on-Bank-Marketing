# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavya-1209/EDA-on-Bike-Sharing/blob/main/EDA_on_Bike_Sharing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/bike+sharing+dataset.zip -d /content/unzipped/
# Out:
# Archive:  /content/bike+sharing+dataset.zip
#   inflating: /content/unzipped/Readme.txt
#   inflating: /content/unzipped/day.csv
#   inflating: /content/unzipped/hour.csv

# %%
import pandas as pd
day=pd.read_csv('/content/unzipped/day.csv')
hour=pd.read_csv('/content/unzipped/hour.csv')
day['type'] = 'day'
hour['type'] = 'hour'

bike_df=pd.concat([day,hour],ignore_index=True)

# %%
bike_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt type  hr
# 0   985  day NaN
# 1   801  day NaN
# 2  1349  day NaN
# ...

# %%
bike_df.shape
# Out:
# (18110, 18)

# %%
bike_df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# type           object
# hr            float64
# dtype: object

# %%
bike_df.isna().sum()
# Out:
# instant         0
# dteday          0
# season          0
# yr              0
# mnth            0
# holiday         0
# weekday         0
# workingday      0
# weathersit      0
# temp            0
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# type            0
# hr            731
# dtype: int64

# %%
bike_df.describe()
# Out:
#             instant        season            yr          mnth       holiday  \
# count  18110.000000  18110.000000  18110.000000  18110.000000  18110.000000
# mean    8354.006405      2.501436      0.502485      6.537051      0.028769
# std     5180.771860      1.107045      0.500008      3.439213      0.167160
# min        1.000000      1.000000      0.000000      1.000000      0.000000
# 25%     3797.250000      2.000000      0.000000      4.000000      0.000000
# 50%     8324.500000      3.000000      1.000000      7.000000      0.000000
# 75%    12851.750000      3.000000      1.000000     10.000000      0.000000
# max    17379.000000      4.000000      1.000000     12.000000      1.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  18110.000000  18110.000000  18110.000000  18110.000000  18110.000000
# mean       3.003424      0.682772      1.424075      0.496922      0.475718
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=bike_df, x='yr', hue='type')
plt.title("Distribution of Bike Sharing")
plt.show()
bike_df.hist(figsize=(20,15), bins=20)
plt.suptitle("Feature Distributions", y=1.02)
plt.tight_layout()
plt.show()

# %%
corr=bike_df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()
